# %% [markdown]
# first import necessary modules

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("spec_RBCL_16s.csv")
df.head()
# Out:
# C:\Users\rah10\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (29,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   UniqueID  TempID  EventID Collector  Apidae  AspergillusSpp  AscosphaeraSpp  \
# 0    17648   17648      NaN        PM     NaN             NaN             NaN
# 1    17649   17649      NaN        PM     NaN             NaN             NaN
# 2    17650   17650      NaN        PM     NaN             NaN             NaN
# 3    17653   17653      NaN        PM     NaN             NaN             NaN
# 4    17654   17654      NaN        PM     NaN             NaN             NaN
#
#    ApicystisSpp  CrithidiaExpoeki  CrithidiaBombi  ...  \
# 0           NaN               NaN             NaN  ...
# 1           NaN               NaN             NaN  ...
# 2           NaN               NaN             NaN  ...
# ...

# %% [markdown]
# drop columns with na

# %%
rbcl = df[['Order', 'Family', 'Genus', 'Species']]

#for i in df.columns:
#    if i.startswith('RBCL'):
    
rbcl_df = [rbcl.append() for i in df.columns if df.columns == df.str.startswith('RBCL')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14328/457206468.py in <module>
#       4 #    if i.startswith('RBCL'):
#       5
# ----> 6 rbcl_df = [rbcl.append() for i in df.columns if df.columns == df.str.startswith('RBCL')]
#
# ~\AppData\Local\Temp/ipykernel_14328/457206468.py in <listcomp>(.0)
#       4 #    if i.startswith('RBCL'):
#       5
# ----> 6 rbcl_df = [rbcl.append() for i in df.columns if df.columns == df.str.startswith('RBCL')]
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
rbcl.head()
# Out:
#          Order      Family         Genus     Species
# 0  Hymenoptera      Apidae   Heterosarus      bakeri
# 1  Hymenoptera  Halictidae  Lasioglossum  ruidosense
# 2  Hymenoptera      Apidae       Andrena  apacheorum
# 3  Hymenoptera  Halictidae  Lasioglossum  ruidosense
# 4  Hymenoptera      Apidae   Heterosarus      bakeri
